# %%
d="d3"
times="dfg_5"
# !rm -r /home/iav/code/edet_dfg_test/automl/efficientdet/tmp/finetune{d}_{times}
# !mkdir /home/iav/code/edet_dfg_test/automl/efficientdet/tmp/finetune{d}_{times}
# !python main.py --mode=train\
    --training_file_pattern=/home/iav/code/bigdata/dfg_efficientdet/test_tfrecord/test* \
    --model_name=efficientdet-{d} \
    --model_dir=/home/iav/code/edet_dfg_test/automl/efficientdet/tmp/finetune{d}_{times}  \
    --ckpt=/home/iav/code/edet_dfg_test/automl/efficientdet/weights/efficientdet-{d}  \
    --train_batch_size=4 \
    --num_examples_per_epoch=1703 --num_epochs=100  \
    --hparams=/home/iav/code/edet_dfg_test/automl/efficientdet/dfg.yaml \
    --save_checkpoints_steps=100 \
# Out:
# 2020-09-10 08:22:33.367484: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...
